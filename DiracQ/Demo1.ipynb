# %%
# %run QDirac2.ipynb

# %%
qc = QuantumCircuit(3)

# %%
qc.init()

# %%
qc.state_vector()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 qc.state_vector()
#
# TypeError: QuantumCircuit.state_vector() missing 1 required positional argument: 'index'

# %%
qc.X(0)

# %%
qc.H(0)

# %%
qc.state_vector()

# %%
st1 = (kron(KET_0, KET_0) + kron(KET_1, KET_1))/np.sqrt(2)

# %%
matmul(reduce(kron, [CNOT, eye(2)]), kron(st1, KET_0))

# %%
import itertools

# %%
list1 = ["A", "B", "C"]
list(itertools.product(list1, list1))
# Out:
# [('A', 'A'),
#  ('A', 'B'),
#  ('A', 'C'),
#  ('B', 'A'),
#  ('B', 'B'),
#  ('B', 'C'),
#  ('C', 'A'),
#  ('C', 'B'),
#  ('C', 'C')]
