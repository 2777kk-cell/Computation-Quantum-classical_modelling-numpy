# %%
# %run QCircuit.ipynb

# %%
qc = QuantumCircuit(2)
qc.initialize()

# %%
qc.STATE_VECTOR
# Out:
# array([[[1.],
#         [0.]],
#
#        [[1.],
#         [0.]]])

# %%
qc.X(0)
qc.H(0)

# %%
qc.X(1)
qc.H(1)

# %%
qc.CX(0, 1)
# Out:
# basis_estimate =X

# %%
qc.STATE_VECTOR
# Out:
# array([[[ 0.70710678],
#         [ 0.70710678]],
#
#        [[ 0.70710678],
#         [-0.70710678]]])
